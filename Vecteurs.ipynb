# %% [markdown]
# On commence par importer les bibliothèques nécessaires. Attention : NE PAS EFFACER !

# %%
# %run Import_bibliotheques.ipynb

# %% [markdown]
# Importation de tableaux enregistrés localement en fichiers csv :

# %%
tableurVersVariables('tableau.csv')    # indiquer le nom complet du fichier à lire si ce n'est pas 'tableau.csv'

# %% [markdown]
# Calcul des variations, utile pour les vecteurs déplacement ou vitesse :

# %%
dx = gradient(x)    # calcule les variations Xi+1 - Xi-1 pour tous les points sauf le premier (Xi+1 - Xi) et le dernier (Xi - xi-1)
dy = gradient(y)

# %% [markdown]
# Tracé de graphique(s) à partir des tableaux précédents :

# %%
#xlim=(-5,5)
#ylim=(-5,5)

fig = go.Figure()

# Points (origines des vecteurs) :
fig.add_trace(go.Scatter(x=x, y=y, mode="markers",
             marker=dict(symbol="cross", size=10, color="blue")))

# Vecteurs : une flèche par point, de (x, y) vers (x + dx, y + dy) :
for xi, yi, dxi, dyi in zip(x, y, dx, dy):
    fig.add_annotation(x=xi + dxi, y=yi + dyi, ax=xi, ay=yi,
                       axref="x", ayref="y", showarrow=True,
                       arrowhead=2, arrowwidth=2, arrowcolor="red")

# Cosmétique du graphique :
fig.update_yaxes(scaleanchor="x", scaleratio=1)    # repère orthonormé
fig.update_xaxes(showgrid=True)    # grille verticale (par défaut)
fig.update_yaxes(showgrid=True)    # grille horizontale (par défaut)
fig.update_layout(showlegend=True,    # légende du graphique
                  height=600)    # hauteur du graphique en pixels ; ex. : 450, 700...
